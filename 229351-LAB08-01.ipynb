# %% [markdown]
# ปฏิบัติการครั้งที่ 8 กระบวนวิชา 229351 Statistical Learning for Data Science
#
# คำชี้แจง
#
# 1. ให้เริ่มทำปฏิบัติการจาก colab notebook ที่กำหนดให้
# 2. ตั้งค่าใน Colab ให้สามารถ share ไฟล์ได้
# 3. ส่งใน Mango

# %% [markdown]
# ดาวน์โหลดข้อมูลการขายรถยนต์ใน link ข้างล่างนี้
# https://donlapark.pages.dev/229351/data/CarSales.csv

# %%
# !wget -O CarSales.csv https://donlapark.pages.dev/229351/data/CarSales.csv
# Out:
# --2025-09-11 02:10:02--  https://donlapark.pages.dev/229351/data/CarSales.csv
# Resolving donlapark.pages.dev (donlapark.pages.dev)... 172.66.47.56, 172.66.44.200, 2606:4700:310c::ac42:2f38, ...
# Connecting to donlapark.pages.dev (donlapark.pages.dev)|172.66.47.56|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1834 (1.8K) [text/csv]
# Saving to: ‘CarSales.csv’
#
# CarSales.csv        100%[===================>]   1.79K  --.-KB/s    in 0s
#
# 2025-09-11 02:10:02 (24.2 MB/s) - ‘CarSales.csv’ saved [1834/1834]

# %%
# import module ที่ต้องใช้
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

# %%
# ฟังก์ชันที่เปลี่ยน string ให้เป็น datetime
def parser(dates):
  return datetime.strptime(dates, '%Y-%m')

# parse_dates ชื่อของคอลัมน์ที่จะเปลี่ยนให้เป็น datetime
# index_col ชื่อของคอลัมน์ที่จะให้เป็น index
# date_parser ฟังก์ชันที่เปลี่ยน string ให้เป็น datetime
data = pd.read_csv('CarSales.csv', parse_dates=['Month'],
                                        index_col='Month',
                                        date_parser=parser)

print (data.tail())
# Out:
#             Sales
# Month
# 1968-08-01  16722
# 1968-09-01  14385
# 1968-10-01  21342
# 1968-11-01  17180
# 1968-12-01  14577
# /tmp/ipython-input-2537936506.py:8: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   data = pd.read_csv('CarSales.csv', parse_dates=['Month'],

# %% [markdown]
# ### Check if the inferred frequency is correct
#
# [list of time series frequencies](https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#offset-aliases)

# %%
print(data.index.inferred_freq)
# Out:
# MS

# %%
y = data['Sales'].astype('float32')

print(y)
# Out:
# Month
# 1960-01-01     6550.0
# 1960-02-01     8728.0
# 1960-03-01    12026.0
# 1960-04-01    14395.0
# 1960-05-01    14587.0
#                ...
# 1968-08-01    16722.0
# 1968-09-01    14385.0
# 1968-10-01    21342.0
# 1968-11-01    17180.0
# 1968-12-01    14577.0
# Name: Sales, Length: 108, dtype: float32

# %%
plt.figure(figsize=(12,6))
y.plot();

# %%
def rmse(y_true,y_pred):
  # Inputs
  # y_true: actual value, y_pred: predicted values
  # Output: RMSE between y_true and y_pred
  return np.sqrt(np.mean(np.square(y_true-y_pred)))

# %% [markdown]
# # Train-Test split

# %%
train = y[:-12]
test = y[-12:]

print(test)
# Out:
# Month
# 1968-01-01    13210.0
# 1968-02-01    14251.0
# 1968-03-01    20139.0
# 1968-04-01    21725.0
# 1968-05-01    26099.0
# 1968-06-01    21084.0
# 1968-07-01    18024.0
# 1968-08-01    16722.0
# 1968-09-01    14385.0
# 1968-10-01    21342.0
# 1968-11-01    17180.0
# 1968-12-01    14577.0
# Name: Sales, dtype: float32

# %%
print(train)
# Out:
# Month
# 1960-01-01     6550.0
# 1960-02-01     8728.0
# 1960-03-01    12026.0
# 1960-04-01    14395.0
# 1960-05-01    14587.0
#                ...
# 1967-08-01    13434.0
# 1967-09-01    13598.0
# 1967-10-01    17187.0
# 1967-11-01    16119.0
# 1967-12-01    13713.0
# Name: Sales, Length: 96, dtype: float32

# %% [markdown]
# ## Holt Winter’s Exponential Smoothing
#
# `ExponentialSmoothing`
#
# ### trend : {“add”, “mul”, “additive”, “multiplicative”, None}, optional
#
#     Type of trend component.
#
# ### damped : bool, optional
#
#     Should the trend component be damped.
#
# ### seasonal : {“add”, “mul”, None}, optional
#
#     Type of seasonal component.
#
# ### seasonal_periods : int, optional
#
#     The number of periods in a complete seasonal cycle, e.g., 4 for quarterly data or 7 for daily data with a weekly cycle.

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing

es = ExponentialSmoothing(train, trend = 'add', damped=False, seasonal=None, seasonal_periods=12)
es_fit = es.fit(optimized=True)
yhat = es_fit.predict('1968-01-01', '1968-12-01')
# Out:
# /tmp/ipython-input-1137874728.py:3: FutureWarning: the 'damped' keyword is deprecated, use 'damped_trend' instead.
#   es = ExponentialSmoothing(train, trend = 'add', damped=False, seasonal=None, seasonal_periods=12)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
print('RMSE:',rmse(test,yhat))
# Out:
# RMSE: 5660.784950869958

# %%
plt.figure(figsize=(12,6))
y.plot()
yhat.plot();

# %%
es = ExponentialSmoothing(train, trend = 'add', damped=False, seasonal='mul', seasonal_periods=12)
es_fit = es.fit(optimized=True)
yhat = es_fit.predict('1968-01-01', '1968-12-01')

print('RMSE:',rmse(test,yhat))
# Out:
# RMSE: 1844.2485176533621
# /tmp/ipython-input-2929677003.py:1: FutureWarning: the 'damped' keyword is deprecated, use 'damped_trend' instead.
#   es = ExponentialSmoothing(train, trend = 'add', damped=False, seasonal='mul', seasonal_periods=12)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %% [markdown]
# Check the parameters of the model.

# %%
#list of parameters
es_fit.params
# Out:
# {'smoothing_level': np.float64(0.3018491313472959),
#  'smoothing_trend': np.float64(0.0),
#  'smoothing_seasonal': np.float64(0.0),
#  'damping_trend': nan,
#  'initial_level': np.float64(10165.15644794876),
#  'initial_trend': np.float64(85.3506563188933),
#  'initial_seasons': array([0.74326636, 0.77438526, 1.16776354, 1.30588877, 1.38171988,
#         1.22346636, 0.8906195 , 0.74942636, 0.66382015, 0.93016903,
#         0.96294255, 0.81677269]),
#  'use_boxcox': False,
#  'lamda': None,
#  'remove_bias': False}
